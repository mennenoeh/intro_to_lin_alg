# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
randoms_2_2 = np.random.beta(a=2, b=2, size=5000)
randoms_4_4 = np.random.beta(a=1, b=10, size=5000)

fig = plt.figure()
d1= sns.displot(x=randoms_2_2, kind='kde')
d2= sns.displot(x=randoms_4_4, kind='kde')

plt.show()
randoms_2_2
# Out:
# array([0.61923967, 0.40237984, 0.52102685, ..., 0.53477201, 0.07856103,
#        0.47616594])
